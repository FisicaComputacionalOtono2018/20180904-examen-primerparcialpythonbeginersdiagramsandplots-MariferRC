# %%
#Autor: Maria Fernanda Rodriguez Castillo 
#Fecha de entrega: 04/09/18
#Tipo de tarea: Ejercicios de examen 
#Ejercicio 1 
#Funcion que calcula el angulo entre 2 vectores. 
import math


x1=float (input('dame la coordenada x del vector a '))
y1=float (input('dame la coordenada y del vector a'))
vector1 = [ x1,y1 ]
print (vector1)
x2=float (input('dame la coordenada x del vector b '))
y2=float (input('dame la coordenada y del vector b'))
vector2 = [ x2,y2 ]
print (vector2)

x=x1*x2
print (x)
y=y1*y2
print(y)
escalar=(x+y) 
print (escalar)
a = math.sqrt(( x1 ** 2 ) + ( y1 ** 2 ))
print (a)
b = math.sqrt(( x2 ** 2 ) + ( y2 ** 2 ))
print(b)
c=(a*b)
print (c)
def f(x,y):
 angle=math.acos((escalar)/(c)) *(180 / math.pi)
 return(angle)
print ('el angulo es')
print(angle)
# Out:
# dame la coordenada x del vector a 1
# dame la coordenada y del vector a2
# [1.0, 2.0]
# dame la coordenada x del vector b 3
# dame la coordenada y del vector b4
# [3.0, 4.0]
# 3.0
# 8.0
# 11.0
# 2.23606797749979
# 5.0
# 11.180339887498949
# el angulo es
# 10.304846468766044

# %%
#Ejercicio 2 
#Funcion que devuelva los 3 angulos con respecto a los ejes x, y y zde un vector tridimencional. 
import math

x=float (input ('dame la coordenada en x del vector r'))
y=float (input ('dame la coordenada en y del vector r'))
z=float (input ('dame la coordenada en z del vector r'))
rvector= [x,y,z]
print (rvector)
rmag=math.sqrt(( x ** 2 ) + ( y ** 2 )+(z ** 2))
print (rmag)
def f(x,y,z):
  anglex =(math.atan(y/x))*(180/math.pi)
  anglez = (math.acos(z/rmag))*(180/math.pi)
  angley= 90-anglex
  return(anglex, angley,anglez)
print (f(x,y,z))
# Out:
# dame la coordenada en x del vector r4
# dame la coordenada en y del vector r7
# dame la coordenada en z del vector r6
# [4.0, 7.0, 6.0]
# 10.04987562112089
# (60.25511870305778, 29.744881296942218, 53.343067045517955)

# %%
#Ejercicio 3 
#Funcion que calcule el producto vectorial entre dos vectores tridimencionales.

import math
import numpy as np
x1=float (input('dame la coordenada x del vector a'))
y1=float (input('dame la coordenada y del vector a'))
z1=float (input('dame la coordenada z del vector a'))
a = np.array([x1, y1, z1])
print (a) 
x2=float (input('dame la coordenada x del vector b'))
y2=float (input('dame la coordenada y del vector b'))
z2=float (input('dame la coordenada z del vector b'))
b = np.array([x2, y2, z2])
print (b)
C =np.cross(a,b)

def F(x,y,z):
  C =np.cross(a,b)
  return (x,y,z)
print('producto vectorial')
print (C)
# Out:
# dame la coordenada x del vector a2
# dame la coordenada y del vector a4
# dame la coordenada z del vector a7
# [2. 4. 7.]
# dame la coordenada x del vector b1
# dame la coordenada y del vector b9
# dame la coordenada z del vector b4
# [1. 9. 4.]
# producto vectorial
# [-47.  -1.  14.]

# %%
#Ejercicio 4 
#Traduzca el diagrama de flujo mostrado en la imagen al lenguaje de python y describa lo que realiza 
x=1
while x<=5:
  if x%3!=0:
    print(x)
    break
  else:
    x=x+2
# Out:
# 1

# %%
#Ejercicio 5 
#Diseñar un algoritmo en python que imprima y sume una serie de numeros 3,6,9,12...99
a=0
serie=list(range(3,102,3))
suma=sum (serie)
print ("numeros",serie)
print ("total",suma)
# Out:
# numeros [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99]
# total 1683

# %%
#Ejercicio 6 
#Escribir un algoritmo en Python que lea 4 numeros y al fin escriba al mayor de los 4. 
a = int(input("dame un numero a "))
b = int(input("dame un numero b  "))
c = int(input("dame un numero c  "))
d = int(input("dame un numero d "))

datos=[a,b,c,d]
x=max(datos)
print ("el mayor es",x)
# Out:
# dame un numero a 4
# dame un numero b  8
# dame un numero c  6
# dame un numero d 1
# el mayor es 8

# %%
#Ejercicio 7
#Algoritmo para calcular la velocidad en (m/s)de los corredores de la carrera de 1.500 metros.

# %%
#Ejercicio 8 
#Escribir un argoritmo que calcule la superficie de un triangulo en funcion de la base y la altura(A=1/2*Base*Altura) 
b=int(input("Ingresa base\n"))
h=int(input("Ingresa altura\n"))
superficie=int((b*h)/2)

def suptriángulo ():
    superficie=int((b*h)/2)
print("la superficie es del triangulo es:", superficie)
# Out:
# Ingresa base
# 2
# Ingresa altura
# 4
# la superficie es del triangulo es: 4

# %%
#Ejercicio 9
#Un sistema de ecuaciones lineales 
#   ax+by=c
#   dx+ey=f
#se puede resolver con las siguientes formulas:
#   x=(ce-bf)/(ae-bd)
#   y=(af-cd)/(ae-bd)
#Diseñar un programa que lea los 2 conjuntos de coeficientes (a,b y c;d,e y f)y visualice los valores de x y y 
import numpy as np
a=float(input('dame un valor para a'))
b=float(input('dame un valor para b'))
c=float(input('dame un valor para c'))

d=float(input('dame un valor para d'))
e=float(input('dame un valor para e'))
f=float(input('dame un valor para f'))

#Cualquiera de las 2 formas es aceptable para encontrar los valos de "x" y "y", ya sea con las formilas o con la solucion del sistema lineal. 

#x=((c*e)-(b*f))/((a*e)-(b*d))
#print (x)
#y=((a*f)-(c*d))/((a*e)-(b*d))
#print (y)

u=np.array([[a,b],[d,e]])
print(u)
v=np.array([c,f])
print (v)
p=np.linalg.solve(u,v)       
print (p)
# Out:
# dame un valor para a2
# dame un valor para b5
# dame un valor para c7
# dame un valor para d1
# dame un valor para e9
# dame un valor para f2
# [[2. 5.]
#  [1. 9.]]
# [7. 2.]
# [ 4.07692308 -0.23076923]

# %%
#Ejercicio 10 
#Diseña un programa que grafique las siguientes funciones en una misma grafica.En el rango de -10 a 15 
#f1(x)=2 x^2 + 5x - 2 
#f2(x)=4x-1 
import numpy as np 
import matplotlib.pyplot as plt 
def F1(x):
  return((2*(x**2)+(5*x)-2))
def F2(x):
  return((4*x)+1)
a=np.arange(-10,15,0.01)
plt.figure(1)
plt.plot(11)
plt.plot 
plt.show
# Out:
# <function matplotlib.pyplot.show>
